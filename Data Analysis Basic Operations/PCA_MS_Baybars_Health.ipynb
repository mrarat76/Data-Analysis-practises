# %%
#RANDOM FOREST MODELİNİ KULLAN!!!
from google.colab import files

# Kaggle API anahtarlarınızın bulunduğu JSON dosyasını seçin
files.upload()
# Out:
#      <input type="file" id="files-0424550d-79f8-485b-a7e1-738bc24a8f01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0424550d-79f8-485b-a7e1-738bc24a8f01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import shutil

# Yüklenen JSON dosyasını ~/.kaggle/ klasörüne taşı
shutil.move('/content/kaggle.json', '/root/.kaggle/kaggle.json')
# Out:
# '/root/.kaggle/kaggle.json'

# %%
import os
import zipfile
import pandas as pd

# Veriyi indir
os.system('kaggle datasets download -d desalegngeb/conversion-predictors-of-cis-to-multiple-sclerosis')

# ZIP dosyasını çıkar
with zipfile.ZipFile('/content/conversion-predictors-of-cis-to-multiple-sclerosis.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
veriler=pd.read_csv("/content/conversion_predictors_of_clinically_isolated_syndrome_to_multiple_sclerosis.csv")

# %%
veriler
# Out:
#      Unnamed: 0  Gender  Age  Schooling  Breastfeeding  Varicella  \
# 0             0       1   34       20.0              1          1
# 1             1       1   61       25.0              3          2
# 2             2       1   22       20.0              3          1
# 3             3       2   41       15.0              1          1
# 4             4       2   34       20.0              2          1
# ..          ...     ...  ...        ...            ...        ...
# 268         268       2   31        8.0              3          1
# 269         269       1   21       15.0              3          3
# 270         270       2   19       12.0              3          3
# 271         271       2   32       15.0              3          3
# 272         272       2   77        6.0              3          3
#
#      Initial_Symptom  Mono_or_Polysymptomatic  Oligoclonal_Bands  LLSSEP  \
# 0                2.0                        1                  0       1
# ...

# %%
# Sütun isimlerini ve veri tiplerini alma
column_names = veriler.columns.tolist()  # Sütun isimleri
column_types = veriler.dtypes.tolist()   # Sütun veri tipleri
#-------------------------------------------------------------------------------------------
categorical_columns = [column_names[i] for i in range(len(column_names)) if 'object' in str(column_types[i])]
numeric_columns = [column_names[i] for i in range(len(column_names)) if 'int' in str(column_types[i]) or 'float' in str(column_types[i])]
#-------------------------------------------------------------------------------------------
numeric_columns.remove("group")
veriler=veriler.drop(["Unnamed: 0","Initial_EDSS","Final_EDSS"],axis=1)
#-------------------------------------------------------------------------------------------
veriler["Schooling"].fillna(veriler["Schooling"].median(), inplace=True)
veriler["Initial_Symptom"].fillna(veriler["Initial_Symptom"].median(), inplace=True)
#veriler["Initial_EDSS"].fillna(veriler["Initial_EDSS"].mode()[0], inplace=True)
#veriler["Final_EDSS"].fillna(veriler["Final_EDSS"].mode()[0], inplace=True)

# %%
veriler
# Out:
#      Gender  Age  Schooling  Breastfeeding  Varicella  Initial_Symptom  \
# 0         1   34       20.0              1          1              2.0
# 1         1   61       25.0              3          2             10.0
# 2         1   22       20.0              3          1              3.0
# 3         2   41       15.0              1          1              7.0
# 4         2   34       20.0              2          1              6.0
# ..      ...  ...        ...            ...        ...              ...
# 268       2   31        8.0              3          1              9.0
# 269       1   21       15.0              3          3              5.0
# 270       2   19       12.0              3          3             13.0
# 271       2   32       15.0              3          3             15.0
# 272       2   77        6.0              3          3              2.0
#
#      Mono_or_Polysymptomatic  Oligoclonal_Bands  LLSSEP  ULSSEP  VEP  BAEP  \
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# İlk 130 veriyi seçin
alt_veri_cercevesi = veriler.iloc[:130]

# Boyut indirgeme işlemi için bağımsız değişkenleri (X) ayarlayın
X = alt_veri_cercevesi

# Veriyi standartlaştırın (PCA veya LDA için önerilir)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA modelini uygulayın:
pca = PCA(n_components=2)  # İndirgenmiş boyut sayısını ayarlayın (örneğin, 2 boyuta indirgiyoruz)
X_reduced = pca.fit_transform(X_scaled)

# Boyut indirgeme sonucunu orijinal veri çerçevesine ekleyin
alt_veri_cercevesi['PCA_Component1'] = X_reduced[:, 0]
alt_veri_cercevesi['PCA_Component2'] = X_reduced[:, 1]

# Değişiklikleri orijinal veri çerçevesine ekleyin
veriler = pd.concat([veriler, alt_veri_cercevesi], ignore_index=True)
# Out:
# <ipython-input-105-2d6f7b3d8a6f>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alt_veri_cercevesi['PCA_Component1'] = X_reduced[:, 0]
# <ipython-input-105-2d6f7b3d8a6f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alt_veri_cercevesi['PCA_Component2'] = X_reduced[:, 1]

# %%
veriler=veriler.drop(["PCA_Component1","PCA_Component2"],axis=1)

# %%
# Her sütundaki null değer sayısını hesaplayın
null_deger_sayisi = veriler.isnull().sum()

# Null değer sayılarını yazdırın
print("Her sütundaki null değer sayıları:")
print(null_deger_sayisi)
# Out:
# Her sütundaki null değer sayıları:
# Gender                     0
# Age                        0
# Schooling                  0
# Breastfeeding              0
# Varicella                  0
# Initial_Symptom            0
# Mono_or_Polysymptomatic    0
# Oligoclonal_Bands          0
# LLSSEP                     0
# ULSSEP                     0
# VEP                        0
# BAEP                       0
# Periventricular_MRI        0
# Cortical_MRI               0
# Infratentorial_MRI         0
# Spinal_Cord_MRI            0
# group                      0
# dtype: int64

# %%
y=veriler["group"]
veriler=veriler.drop("group",axis=1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numeric_columns = veriler.select_dtypes(include=['number'])


veriler[numeric_columns.columns] = scaler.fit_transform(numeric_columns)

# %%
def parcalamaIslemi(A,B):
  from sklearn.model_selection import train_test_split
  X_train, X_test, Y_train, Y_test = train_test_split(A, B,test_size=0.2,random_state=42)
  return X_train, X_test, Y_train, Y_test

# %%
MyX_train, MyX_test, MyY_train, MyY_test=parcalamaIslemi(veriler, y)

# %%
import pandas as pd
from sklearn import ensemble, gaussian_process, linear_model, naive_bayes, neighbors, svm, tree, discriminant_analysis
from sklearn.metrics import accuracy_score

# Define the list of different machine learning algorithms
MLA = [
    # Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),

    # Gaussian Processes
    gaussian_process.GaussianProcessClassifier(),

    # GLM
    linear_model.LogisticRegressionCV(),
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),

    # Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),

    # Nearest Neighbor
    neighbors.KNeighborsClassifier(),

    # SVM
    svm.SVC(probability=True),
    svm.NuSVC(probability=True),
    svm.LinearSVC(),

    # Trees
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),

    # Discriminant Analysis
    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis()
]

# Create empty lists to store the results
algo_names = []
train_accuracy_scores = []
test_accuracy_scores = []

# Iterate over each algorithm in MLA
for model in MLA:
    # Fit the model on the training data
    model.fit(MyX_train, MyY_train)

    # Make predictions on the training data
    train_y_pred = model.predict(MyX_train)

    # Calculate the accuracy for the training data
    train_accuracy = accuracy_score(MyY_train, train_y_pred)

    # Make predictions on the testing data
    test_y_pred = model.predict(MyX_test)

    # Calculate the accuracy for the testing data
    test_accuracy = accuracy_score(MyY_test, test_y_pred)

    # Store the results in the lists
    algo_names.append(type(model).__name__)
    train_accuracy_scores.append(train_accuracy)
    test_accuracy_scores.append(test_accuracy)

# Create a dataframe from the results
results_df = pd.DataFrame({
    'Algorithm': algo_names,
    'Training Accuracy': train_accuracy_scores,
    'Testing Accuracy': test_accuracy_scores
})

results_df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#                         Algorithm  Training Accuracy  Testing Accuracy
# 0              AdaBoostClassifier           0.909938          0.851852
# 1               BaggingClassifier           0.990683          0.876543
# 2            ExtraTreesClassifier           1.000000          0.938272
# 3      GradientBoostingClassifier           0.990683          0.901235
# 4          RandomForestClassifier           1.000000          0.913580
# 5       GaussianProcessClassifier           1.000000          0.925926
# 6            LogisticRegressionCV           0.866460          0.851852
# 7     PassiveAggressiveClassifier           0.801242          0.790123
# 8               RidgeClassifierCV           0.835404          0.839506
# 9                   SGDClassifier           0.804348          0.839506
# ...

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def calculate_metrics(y_true, y_pred):
    # Calculate F1 score
    f1 = f1_score(y_true, y_pred, average='weighted')

    # Calculate precision
    precision = precision_score(y_true, y_pred, average='weighted')

    # Calculate sensitivity (recall)
    sensitivity = recall_score(y_true, y_pred, average='weighted')

    # Calculate specificity
    unique_labels = set(y_true)
    specificity = {}
    for label in unique_labels:
        true_negatives = sum((y_true != label) & (y_pred != label))
        false_positives = sum((y_true != label) & (y_pred == label))
        specificity[label] = true_negatives / (true_negatives + false_positives)

    return f1, precision, sensitivity, specificity

def calculate_accuracy(y_true, y_pred):
    correct_predictions = 0
    total_predictions = len(y_true)

    for true_label, pred_label in zip(y_true, y_pred):
        if true_label == pred_label:
            correct_predictions += 1

    accuracy = correct_predictions / total_predictions
    return accuracy

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=50,criterion="gini")
rfc.fit(MyX_train, MyY_train)
y_predRF=rfc.predict(MyX_test)

# %%
f1, precision, sensitivity, specificity = calculate_metrics(MyY_test, y_predRF)
print("F1 Score:", f1)
print("Precision:", precision)
print("Sensitivity (Recall):", sensitivity)
print("Specificity:", specificity)
#------------------------------------------------------------
accuracyLG=calculate_accuracy(MyY_test, y_predRF)
print("Accuracy",accuracyLG)
# Out:
# F1 Score: 0.9090878384084038
# Precision: 0.9231824417009601
# Sensitivity (Recall): 0.9135802469135802
# Specificity: {1: 0.72, 2: 1.0}
# Accuracy 0.9135802469135802

# %%
from sklearn.model_selection import GridSearchCV

# İncelemek istediğiniz hiperparametre kombinasyonları
param_grid = {
    'n_estimators': [50, 12,30],
    'max_depth': [None, 10, 15,25],
    'min_samples_split': [2,3,4],
    'min_samples_leaf': [1,3,5]
}

# Grid Search modelini oluşturun
grid_search = GridSearchCV(estimator=RandomForestClassifier(criterion="gini"),
                           param_grid=param_grid,
                           scoring='accuracy',
                           cv=5,  # 5 katlı çapraz doğrulama kullanabilirsiniz
                           n_jobs=-1,  # Tüm işlemcileri kullan
                           verbose=2)  # İlerlemeyi göster

# Grid Search'i verilerinize uygulayın
grid_search.fit(MyX_train, MyY_train)

# En iyi hiperparametreleri ve sonucu alın
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("En iyi hiperparametreler:", best_params)
print("En iyi doğruluk (accuracy) skoru:", best_score)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# En iyi hiperparametreler: {'max_depth': 25, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 12}
# En iyi doğruluk (accuracy) skoru: 0.8787499999999999

# %%
from sklearn.ensemble import RandomForestClassifier

# En iyi hiperparametreleri kullanarak RandomForestClassifier modelini oluşturun
best_rfc = RandomForestClassifier(max_depth=15, min_samples_leaf=1, min_samples_split=3, n_estimators=30)

# Modeli eğitin
best_rfc.fit(MyX_train, MyY_train)

# Test verileri üzerinde tahmin yapın
y_pred_best_rfc = best_rfc.predict(MyX_test)

# %%
f1, precision, sensitivity, specificity = calculate_metrics(MyY_test, y_pred_best_rfc)
print("F1 Score:", f1)
print("Precision:", precision)
print("Sensitivity (Recall):", sensitivity)
print("Specificity:", specificity)
#------------------------------------------------------------
accuracyLG=calculate_accuracy(MyY_test, y_pred_best_rfc)
print("Accuracy",accuracyLG)
# Out:
# F1 Score: 0.9090878384084038
# Precision: 0.9231824417009601
# Sensitivity (Recall): 0.9135802469135802
# Specificity: {1: 0.72, 2: 1.0}
# Accuracy 0.9135802469135802

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# Gradient Boosting Classifier modelini oluşturun
model = GradientBoostingClassifier()

# Ayarlanacak hiperparametreleri ve aralıklarını belirtin
param_grid = {
    'n_estimators': [100, 200, 300,20,30,40],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5,6,7,8,9]
}

# Grid Search ile hiperparametre ayarlaması yapın
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(MyX_train, MyY_train)

# En iyi hiperparametreleri ve en iyi modeli alın
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Test seti üzerinde modelin performansını değerlendirin
accuracy = best_model.score(MyX_test, MyY_test)

# Sonuçları yazdırın
print("En iyi hiperparametreler:", best_params)
print("Test seti doğruluk değeri:", accuracy)
# Out:
# Fitting 5 folds for each of 126 candidates, totalling 630 fits
# En iyi hiperparametreler: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# Test seti doğruluk değeri: 0.9012345679012346

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Belirlediğiniz parametre değerleri ile GradientBoostingClassifier modelini oluşturun
model_gradient = GradientBoostingClassifier(learning_rate=0.1, max_depth=3, n_estimators=200)

# Modeli eğitim verileri üzerinde eğitin (X_train ve y_train)
model_gradient.fit(MyX_train, MyY_train)
y_pred_gradient = model_gradient.predict(MyX_test)

# %%
f1, precision, sensitivity, specificity = calculate_metrics(MyY_test, y_pred_gradient)
print("F1 Score:", f1)
print("Precision:", precision)
print("Sensitivity (Recall):", sensitivity)
print("Specificity:", specificity)
#------------------------------------------------------------
accuracyLG=calculate_accuracy(MyY_test, y_pred_gradient)
print("Accuracy",accuracyLG)
# Out:
# F1 Score: 0.8951205173427396
# Precision: 0.9135802469135802
# Sensitivity (Recall): 0.9012345679012346
# Specificity: {1: 0.68, 2: 1.0}
# Accuracy 0.9012345679012346

# %%
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# Extra Trees Classifier modelini oluşturun
model = ExtraTreesClassifier()

# Ayarlanacak hiperparametreleri ve aralıklarını belirtin
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Grid Search ile hiperparametre ayarlaması yapın
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(MyX_train, MyY_train)

# En iyi hiperparametreleri ve en iyi modeli alın
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Test seti üzerinde modelin performansını değerlendirin
accuracy = best_model.score(MyX_test, MyY_test)

# Sonuçları yazdırın
print("En iyi hiperparametreler:", best_params)
print("Test seti doğruluk değeri:", accuracy)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# En iyi hiperparametreler: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Test seti doğruluk değeri: 0.9135802469135802

# %%
y_pred_extraTree=best_model.predict(MyX_test)

# %%
f1, precision, sensitivity, specificity = calculate_metrics(MyY_test, y_pred_extraTree)
print("F1 Score:", f1)
print("Precision:", precision)
print("Sensitivity (Recall):", sensitivity)
print("Specificity:", specificity)
#------------------------------------------------------------
accuracyLG=calculate_accuracy(MyY_test, y_pred_extraTree)
print("Accuracy",accuracyLG)
# Out:
# F1 Score: 0.9090878384084038
# Precision: 0.9231824417009601
# Sensitivity (Recall): 0.9135802469135802
# Specificity: {1: 0.72, 2: 1.0}
# Accuracy 0.9135802469135802
